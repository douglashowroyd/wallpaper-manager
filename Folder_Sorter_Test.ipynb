# %%
import ctypes
import os
import numpy as np
import pandas as pd
import shutil

# %%
path= "C:\\Users\\DLaptop\\Desktop\\wallpaper\\test"

# %%
for file in folder_dir:
    file_name = path + "\\" + file
    if os.path.isdir(file_name)==True:
        print( file, "is a folder.")
    else: 
        print(file, "No")

# %%
data2 = []
df=pd.DataFrame(data2, columns=['name','ext'])
print(df)

# %%
df=pd.DataFrame([1])
df

# %%
data=pd.DataFrame([[1, 2]],columns=['a','b'])
df=df.append(data)
df

# %%
df2 = pd.DataFrame(['bob','jpg'], columns=['name','ext'])

# %%
df2 = pd.DataFrame([['bob','jpg']], columns=['name','ext'])
df=df.append(df2, ignore_index=True, sort = True)
print(df)

# %%
df.to_csv('out.csv')

# %%
if 'bob' in df['name'].values:
    print("In")
else:
    print("not in")

# %%
os.chdir(path)

# %%
import ctypes
import os
import numpy as np
import pandas as pd
import shutil


def Move_Into_Temp():
    '''Makes an empty temp folder, 
            moves the old temp folder to a new one if such a folder exists 
            then moves all folders into temp folder'''
    folder_dir = os.listdir()
    if 'Temp' in folder_dir:
        new_temp='Temp'
        count = 0
        while new_temp in folder_dir:
            count += 1
            new_temp = 'Temp-%d' % (count,) 
        os.mkdir(new_temp)
        folder_dir.append(new_temp)
        folder_dir.remove('Temp')
        for file in os.listdir('Temp'):
            shutil.move(os.path.join('Temp',file),os.path.join(new_temp,file))
            print('Moving %s from Temp folder to' % (file,), new_temp)
    else:
        os.mkdir('Temp')
    
    # move all files in path to temp folder
    for file in folder_dir:
        shutil.move(file, os.path.join('Temp',file))
        print('Moving %s to Temp folder' % (file,))

    
    


def Temp_To_New():
    '''Move all files to New folder from temp folder'''
    
    print('Creating New folder')
    os.mkdir('New')
    print('Creating Used folder')
    os.mkdir('Used')
    print('Creating Errors folder')    
    os.mkdir('Errors')


    # take list of all files and directories in temp
    folder_dir = os.listdir('Temp')
    
    while len(folder_dir)>0:
    
        root, dirs, files = next(os.walk('Temp'))
        
        
        # first deal with loose files
        for file in files:
            head = file.split(".")[0]
            tail = file.split(".")[-1]
    
     
            # if not a picture move to error file and we will deal with it later
            if tail not in ['pjpeg', 'gif', 'bmp','jpg','jpeg','png']:
                #move to main folder first to avoid bad interactions
                shutil.move(os.path.join('Temp',file),file)
                dst_file = os.path.join('Errors', file)
                tail = '.' + tail
                # now check no name overlaps
                count = 0
                while os.path.exists(dst_file):
                    count += 1
                    dst_file = os.path.join('Errors', '%s-%d%s' % (head, count, tail))
                print('Renaming %s to %s' % (file, dst_file))
                shutil.move(file, dst_file)
                continue

    
    
            # now check no name overlaps then move to New folder   
            shutil.move(os.path.join('Temp',file),file)
            
            dst_file = os.path.join('New', file)
            tail = '.' + tail
            # rename if necessary
            count = 0
            while os.path.exists(dst_file):
                count += 1
                dst_file = os.path.join('New', '%s-%d%s' % (head, count, tail))
            print('Renaming %s to %s' % (file, dst_file))
            shutil.move(file, dst_file)     

    
      
        # takes all objects in all folders in temp and moves them into temp themselves, then deletes the empty folders
        for folder_name in dirs:
            second_path = os.path.join('Temp', folder_name)
            
            second_root, second_dirs, second_files = next(os.walk(second_path))
            
            # move files from folder_name to temp, renaming where needed
            for file in second_files:
                head = file.split(".")[0]
                tail = '.' + file.split(".")[-1]
                
                # now check no name overlaps
                shutil.move(os.path.join('Temp',folder_name,file), file)
                dst_file = os.path.join('Temp', file)
                count = 0
                while os.path.exists(dst_file):
                    count += 1
                    dst_file = os.path.join('Temp', '%s-%d%s' % (head, count, tail))
                print('Renaming %s to %s' % (file, dst_file))
                shutil.move(file, dst_file)
                
                
                
            # move folders to temp folder
            for folder in second_dirs:
                # first move to main folder
                if folder == 'New':
                    shutil.move(os.path.join('Temp',folder_name,folder),'New-1')
                    folder = 'New-1'
                elif folder == 'Temp':
                    shutil.move(os.path.join('Temp',folder_name,folder),'temp-1')
                    folder = 'Temp-1'
                elif folder == 'Used':
                    shutil.move(os.path.join('temp',folder_name,folder),'Used-1')
                    folder = 'Used-1'
                elif folder == 'Errors':
                    shutil.move(os.path.join('Temp',folder_name,folder),'Errors-1')
                    folder = 'Errors-1'
                else:
                    shutil.move(os.path.join('Temp',folder_name,folder),folder)
                
                # now check no name overlaps
                dst_dir = os.path.join('Temp', folder)
                count = 0
                while os.path.exists(dst_dir):
                    count += 1
                    dst_dir = os.path.join('Temp', '%s-%d' % (folder, count))
                print('Renaming %s to %s' % (folder, dst_dir))
                shutil.move(folder, dst_dir)
                
                
            os.rmdir(os.path.join('Temp',folder_name))
            
        # recheck temp folder
        folder_dir = os.listdir('Temp')
        
    
    shutil.rmtree('Temp')
     



        

    
    
def DataFrame_Populate(path):
    '''start data frame of all images'''
    data = []
    df = pd.DataFrame(data, columns = ['Names','Extension','Kept','Rejected','Total Score','New or Used', 'Weight'])
    
    
    newdir_list = os.listdir('New')
    
    
    for file in newdir_list:
        head = file.split(".")[0]
        tail = file.split(".")[-1]
    
    
        # add file and etension to dataframe
        df2 = pd.DataFrame([[head,tail,0,0,0,0,1]], columns=['Names','Extension','Kept','Rejected','Total Score','Weight'])
        df=df.append(df2, ignore_index=True, sort = True)
    

    cols = ['Names','Extension','Kept','Rejected','Total Score','New or Used','Weight']
    df = df[cols]
    print(df.head())
    df.to_csv(os.path.join(path,'wallpaper_data.csv'))
    print('A list of all your wallpapers can be found in your wallpaper folder as a .csv file')
        
        
    # need to analyse each pic at the end for rgb values

    
    
    
    
    
    
def Check_Errors_Folder():
    '''Informs user about the number of errors or delete folder if empty'''
    no_of_errors = len(os.listdir('Errors'))
    if  no_of_errors == 1:
        print("There was 1 incompatible file.")
        print("It can be found in", os.path.join(path,'Errors'))
        print("If you would like to use this file as a wallpaper, please convert it to a valid format and rerun this program.")

    elif no_of_errors > 1:
        print("There were ", no_of_errors," incompatible files.")
        print("They can be found in", os.path.join(path,'Errors'))
        print("If you would like to use any of those files as wallpapers, please convert them to a valid format and rerun this program.")
    else:
        shutil.rmtree('Errors')
# Out:
# Moving Errors to temp folder
# Moving New to temp folder
# Moving Used to temp folder
# Moving wallpaper_data.csv to temp folder
# Creating New folder
# Creating Used folder
# Creating Errors folder
# Renaming wallpaper_data.csv to Errors\wallpaper_data.csv
# Errors\wallpaper_data.csv
# Renaming bob - Copy.txt to temp\bob - Copy.txt
# temp\bob - Copy.txt
# Renaming bob-1.txt to temp\bob-1.txt
# temp\bob-1.txt
# Renaming bob-2.txt to temp\bob-2.txt
# temp\bob-2.txt
# Renaming bob.txt to temp\bob.txt
# temp\bob.txt
# Renaming wallpaper_data-1.csv to temp\wallpaper_data-1.csv
# temp\wallpaper_data-1.csv
# Renaming wallpaper_data-2.csv to temp\wallpaper_data-2.csv
# temp\wallpaper_data-2.csv
# Renaming wallpaper_data-3.csv to temp\wallpaper_data-3.csv
# temp\wallpaper_data-3.csv
# Renaming wallpaper_data-4.csv to temp\wallpaper_data-4.csv
# temp\wallpaper_data-4.csv
# Renaming wallpaper_data-5.csv to temp\wallpaper_data-5.csv
# temp\wallpaper_data-5.csv
# Renaming wallpaper_data.csv to temp\wallpaper_data.csv
# temp\wallpaper_data.csv
# Renaming gandalf - Copy (10) - Copy - Copy - Copy.png to temp\gandalf - Copy (10) - Copy - Copy - Copy.png
# temp\gandalf - Copy (10) - Copy - Copy - Copy.png
# Renaming gandalf - Copy (10) - Copy - Copy(1)(1).png to temp\gandalf - Copy (10) - Copy - Copy(1)(1).png
# temp\gandalf - Copy (10) - Copy - Copy(1)(1).png
# Renaming gandalf - Copy (10) - Copy - Copy(1).png to temp\gandalf - Copy (10) - Copy - Copy(1).png
# temp\gandalf - Copy (10) - Copy - Copy(1).png
# Renaming gandalf - Copy (10) - Copy - Copy.png to temp\gandalf - Copy (10) - Copy - Copy.png
# temp\gandalf - Copy (10) - Copy - Copy.png
# Renaming gandalf - Copy (11) - Copy - Copy - Copy(1)(1).png to temp\gandalf - Copy (11) - Copy - Copy - Copy(1)(1).png
# temp\gandalf - Copy (11) - Copy - Copy - Copy(1)(1).png
# Renaming gandalf - Copy (11) - Copy - Copy - Copy(1).png to temp\gandalf - Copy (11) - Copy - Copy - Copy(1).png
# temp\gandalf - Copy (11) - Copy - Copy - Copy(1).png
# Renaming gandalf - Copy (11) - Copy - Copy - Copy.png to temp\gandalf - Copy (11) - Copy - Copy - Copy.png
# temp\gandalf - Copy (11) - Copy - Copy - Copy.png
# Renaming gandalf - Copy (11) - Copy - Copy(1).png to temp\gandalf - Copy (11) - Copy - Copy(1).png
# temp\gandalf - Copy (11) - Copy - Copy(1).png
# Renaming gandalf - Copy (11) - Copy - Copy.png to temp\gandalf - Copy (11) - Copy - Copy.png
# temp\gandalf - Copy (11) - Copy - Copy.png
# Renaming gandalf - Copy (12) - Copy - Copy(1)(1)(1).png to temp\gandalf - Copy (12) - Copy - Copy(1)(1)(1).png
# temp\gandalf - Copy (12) - Copy - Copy(1)(1)(1).png
# Renaming gandalf - Copy (12) - Copy - Copy(1)(1).png to temp\gandalf - Copy (12) - Copy - Copy(1)(1).png
# temp\gandalf - Copy (12) - Copy - Copy(1)(1).png
# Renaming gandalf - Copy (12) - Copy - Copy(1).png to temp\gandalf - Copy (12) - Copy - Copy(1).png
# temp\gandalf - Copy (12) - Copy - Copy(1).png
# New\gandalf - Copy (10) - Copy - Copy.png
# Renaming gandalf - Copy (11) - Copy - Copy - Copy(1)(1).png to New\gandalf - Copy (11) - Copy - Copy - Copy(1)(1).png
# New\gandalf - Copy (11) - Copy - Copy - Copy(1)(1).png
# Renaming gandalf - Copy (11) - Copy - Copy - Copy(1).png to New\gandalf - Copy (11) - Copy - Copy - Copy(1).png
# New\gandalf - Copy (11) - Copy - Copy - Copy(1).png
# Renaming gandalf - Copy (11) - Copy - Copy - Copy.png to New\gandalf - Copy (11) - Copy - Copy - Copy.png
# New\gandalf - Copy (11) - Copy - Copy - Copy.png
# Renaming gandalf - Copy (11) - Copy - Copy(1).png to New\gandalf - Copy (11) - Copy - Copy(1).png
# New\gandalf - Copy (11) - Copy - Copy(1).png
# Renaming gandalf - Copy (11) - Copy - Copy.png to New\gandalf - Copy (11) - Copy - Copy.png
# New\gandalf - Copy (11) - Copy - Copy.png
# Renaming gandalf - Copy (12) - Copy - Copy(1)(1)(1).png to New\gandalf - Copy (12) - Copy - Copy(1)(1)(1).png
# New\gandalf - Copy (12) - Copy - Copy(1)(1)(1).png
# Renaming gandalf - Copy (12) - Copy - Copy(1)(1).png to New\gandalf - Copy (12) - Copy - Copy(1)(1).png
# New\gandalf - Copy (12) - Copy - Copy(1)(1).png
# Renaming gandalf - Copy (12) - Copy - Copy(1).png to New\gandalf - Copy (12) - Copy - Copy(1).png
# New\gandalf - Copy (12) - Copy - Copy(1).png
# Renaming gandalf - Copy (12) - Copy - Copy.png to New\gandalf - Copy (12) - Copy - Copy.png
# New\gandalf - Copy (12) - Copy - Copy.png
# Renaming gandalf - Copy (13) - Copy - Copy(1).png to New\gandalf - Copy (13) - Copy - Copy(1).png
# New\gandalf - Copy (13) - Copy - Copy(1).png
# Renaming gandalf - Copy (13) - Copy - Copy.png to New\gandalf - Copy (13) - Copy - Copy.png
# New\gandalf - Copy (13) - Copy - Copy.png
# Renaming gandalf - Copy (2) - Copy(1)(1)(1).png to New\gandalf - Copy (2) - Copy(1)(1)(1).png
# New\gandalf - Copy (2) - Copy(1)(1)(1).png
# Renaming gandalf - Copy (2) - Copy(1)(1).png to New\gandalf - Copy (2) - Copy(1)(1).png
# New\gandalf - Copy (2) - Copy(1)(1).png
# Renaming gandalf - Copy (2) - Copy(1).png to New\gandalf - Copy (2) - Copy(1).png
# New\gandalf - Copy (2) - Copy(1).png
# Renaming gandalf - Copy (2) - Copy.png to New\gandalf - Copy (2) - Copy.png
# New\gandalf - Copy (2) - Copy.png
# Renaming gandalf - Copy (2)(1) - Copy.png to New\gandalf - Copy (2)(1) - Copy.png
# New\gandalf - Copy (2)(1) - Copy.png
# Renaming gandalf - Copy (2)(1).png to New\gandalf - Copy (2)(1).png
# New\gandalf - Copy (2)(1).png
# Renaming gandalf - Copy (2).png to New\gandalf - Copy (2).png
# New\gandalf - Copy (2).png
# Renaming gandalf - Copy (3) - Copy(1).png to New\gandalf - Copy (3) - Copy(1).png
# New\gandalf - Copy (3) - Copy(1).png
# Renaming mountain - Copy - Copy.jpg to New\mountain - Copy - Copy.jpg
# New\mountain - Copy - Copy.jpg
# Renaming mountain - Copy.jpg to New\mountain - Copy.jpg
# New\mountain - Copy.jpg
# Renaming mountain.jpg to New\mountain.jpg
# New\mountain.jpg
# Renaming second level gand.png to New\second level gand.png
# New\second level gand.png
# Renaming second level mountain.jpg to New\second level mountain.jpg
# New\second level mountain.jpg
# Renaming wallpaper_data-1.csv to Errors\wallpaper_data-1.csv
# Errors\wallpaper_data-1.csv
# Renaming wallpaper_data-2.csv to Errors\wallpaper_data-2.csv
# Errors\wallpaper_data-2.csv
# Renaming wallpaper_data-3.csv to Errors\wallpaper_data-3.csv
# Errors\wallpaper_data-3.csv
# Renaming wallpaper_data-4.csv to Errors\wallpaper_data-4.csv
# Errors\wallpaper_data-4.csv
# Renaming wallpaper_data-5.csv to Errors\wallpaper_data-5.csv
# Errors\wallpaper_data-5.csv
# Renaming wallpaper_data.csv to Errors\wallpaper_data-6.csv
# Errors\wallpaper_data-6.csv
#                                             Names Extension Kept Rejected  \
# 0        gandalf - Copy (10) - Copy - Copy - Copy       png    0        0
# 1         gandalf - Copy (10) - Copy - Copy(1)(1)       png    0        0
# 2            gandalf - Copy (10) - Copy - Copy(1)       png    0        0
# 3               gandalf - Copy (10) - Copy - Copy       png    0        0
# 4  gandalf - Copy (11) - Copy - Copy - Copy(1)(1)       png    0        0
#
#   Total Score
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# A list of all your wallpapers can be found in your wallpaper folder as a .csv file
# There were  11  incompatible files.
# They can be found in C:\Users\DLaptop\Desktop\wallpaper\test\Errors
# If you would like to use any of those files as wallpapers, please convert them to a valid format and rerun this program.

# %%
file=folder_dir[1]
new_path = os.path.join(path,'temp')
os.mkdir(new_path)
shutil.move(os.path.join(path,file), os.path.join(new_path,file))

# %%
path = "C:\\Users\\DLaptop\\Desktop\\wallpaper\\test"
file_name="d"
name = file_name.split(".")[0]
extension = file_name.split(".")[-1]
print(name)
print(extension)
if extension not in ['jpg','jpeg','png']:
    os.rename(os.path.join(path,file_name), os.path.join(path,'errors',file_name))

# %%
path
# Out:
# 'C:\\Users\\DLaptop\\Desktop\\wallpaper\\test'

# %%
os.listdir()
# Out:
# ['bob.txt', 'h.png', 'New', 'temp', 'temp(1)', 'Used']

# %%
file = 'temp\\'+os.listdir('temp')[0]
file
# Out:
# 'temp\\h - Copy.png'

# %%
shutil.move(file,'h - Copy.png')
# Out:
# 'h - Copy.png'

# %%
os.chdir(path)

# %%
root, dirs, files = next(os.walk('temp'))
files
# Out:
# ['h - Copy.png']

# %%
os.listdir()

# %%
    folder_dir = os.listdir()
    if 'temp' in folder_dir:
        new_temp='temp'
        while new_temp in folder_dir:
            new_temp = new_temp + '(1)'
        os.mkdir(new_temp)
        folder_dir.append(new_temp)
        folder_dir.remove('temp')
        for file in os.listdir('temp'):
             shutil.move(os.path.join('temp',file),os.path.join(new_temp,file))    
    else:
        os.mkdir('temp')
    
    '''move all files in path to temp folder'''
    for file in folder_dir:
        shutil.move(file, os.path.join('temp',file))

# %%
new_temp

# %%
folder_dir
